# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys, itertools
sys.path.append(str(Path.cwd() / 'util/'))
from qubit_templates import *
from functions import *
from ChipDesign import *

# %%
l_Squid = [False, True]
l_Bandage = [False, True]

# %%
from pathlib import Path

# 対象ディレクトリ
dir_path = Path("config/JJ")

# 拡張子が .yaml または .yml のファイルを再帰的に取得
yaml_files = list(dir_path.rglob("*.yaml")) + list(dir_path.rglob("*.yml"))


for fin in yaml_files:
    print("*" * 50)
    print("**", fin)
    print("*" * 50)   
    
    if "3D" in str(fin):
        common_config = "config/common_3D.yaml"
    else:
        common_config = "config/common.yaml"
    config = load_config( [common_config, fin] ) # common config will be overwritten by value in the right 

    for Squid, Bandage in itertools.product(l_Squid, l_Bandage):
        config["JJ_squid"] = Squid
        config["JJ_bandage"] = Bandage
        JJ = device_JJ( config )
        qp(JJ)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# **************************************************
# ** config/JJ/manhattan_3D_photolitho.yaml
# **************************************************
# config/common_3D.yaml
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# **************************************************
# ** config/JJ/manhattan_2D.yaml
# **************************************************
# config/common.yaml
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ...

# %%
for fin in yaml_files:
    print("*" * 50)
    print("**", fin)
    print("*" * 50)   

    if "3D" in str(fin):
        common_config = "config/common_3D.yaml"
    else:
        common_config = "config/common.yaml"
    config = load_config( [common_config, fin] ) # common config will be overwritten by value in the right 

    D = sweep_chipdesign( config )
    D.center = (0,0)
    qp(D)
# Out:
# **************************************************
# ** config/JJ/manhattan_3D_photolitho.yaml
# **************************************************
# config/common_3D.yaml
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# **************************************************
# ** config/JJ/manhattan_2D.yaml
# **************************************************
# config/common.yaml
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# **************************************************
# ** config/JJ/dolan_3D.yaml
# **************************************************
# config/common_3D.yaml
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# **************************************************
# ** config/JJ/dolan_3D_photolitho.yaml
# **************************************************
# config/common_3D.yaml
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# ...
